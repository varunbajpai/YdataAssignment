# %%
from keras.models import load_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
model = load_model('my_model_5_features.h5')
time_step_size = 4

# %%
test_data = pd.read_csv('data.csv')
test_data = test_data.iloc[:,:].values

# %%
X_test = []
Y_test = []
for i in range(time_step_size,len(test_data)):
    X_test.append(test_data[i-time_step_size:i])
    Y_test.append(test_data[i][0])
Y_test = np.array(Y_test)
X_test = np.array(X_test)

# %%
X_test = X_test[len(X_test)-20:]
Y_test = Y_test[len(Y_test)-20:]

# %%
predicted_level = model.predict(X_test)

# %%
predicted_stock_price, Y_test
# Out:
# (array([[0.01668149],
#         [0.06614732],
#         [0.04632453],
#         [0.02933634],
#         [0.03124642],
#         [0.02314981],
#         [0.05149793],
#         [0.11440951],
#         [0.12392768],
#         [0.01909467],
#         [0.03155432],
#         [0.14048484],
#         [0.04298957],
#         [0.0432451 ],
#         [0.05138849],
#         [0.05272195],
#         [0.10407649],
#         [0.15417975],
#         [0.04476991],
#         [0.05051571]], dtype=float32),
#  array([0.06312222, 0.08020764, 0.03659486, 0.06132376, 0.07795956,
#         0.03686463, 0.04468795, 0.11662656, 0.05907567, 0.04423834,
#         0.03974217, 0.03344754, 0.04243987, 0.01591251, 0.05278105,
#         0.04783527, 0.09594421, 0.0957194 , 0.04850969, 0.15184651]))

# %%
plt.plot(Y_test, color = 'red', label = 'Real Value')
plt.plot(predicted_level, color = 'blue', label = 'Predicted Value')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
